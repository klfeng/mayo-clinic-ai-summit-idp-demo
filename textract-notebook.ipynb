# %%
# !pip install -qq -r requirements.txt

# %%
from src.textract_processor import TextractProcessor
from src.extractor import Extractor
from src.evaluator import Evaluator
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# # Intelligent Document Processing using Amazon Textract and Bedrock

# %% [markdown]
# #### The purpose of this notebook is to demonstrate how to transform unstructured medical data into structured data. The following classes have already been implemented to be used in this notebook:
# * TextractProcessor: Text extraction using Amazon Textract
# * Extractor: Metadata extraction using Amazon Bedrock and Anthropic Claude
# * Evaluator: LLM evaluation using exact match, fuzzy match, and LLM match

# %% [markdown]
# ## Convert PDF document to markdown file using Amazon Textract

# %% [markdown]
# #### Initialize TextractProcessor class

# %%
textractor = TextractProcessor()

# %% [markdown]
# #### Start document analysis and get Textract Job ID

# %%
job_id = textractor.start_textract(file_path = "input_files/patient_02.pdf")

# %%
job_id
# Out:
# '47396342adf5c076ffe7bafbbd13c8fe930c120fc18d73ebd9c16c6e683d7ecd'

# %% [markdown]
# #### Retrieve Textract response using the Job ID

# %%
textract_response = textractor.get_textract_response(job_id = job_id)

# %%
textract_response
# Out:
# {'DocumentMetadata': {'Pages': 4},
#  'JobStatus': 'SUCCEEDED',
#  'NextToken': 'wLq2OMFGVHifKZBMCvOdA/TU8jiEIauMVsS7PWBokcanFUIqYoCa7Wz94+1XkOomvxAQw+4s5HP729EfOh8rGw/TqbY/opwVacUGxrF1OM8afdumSTKyw84MHx3zg9eEiDA4UnI=',
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 1.0,
#      'Height': 1.0,
#      'Left': 0.0,
#      'Top': 0.0},
#     'Polygon': [{'X': 0.0, 'Y': 2.0999438277158333e-07},
#      {'X': 1.0, 'Y': 0.0},
#      {'X': 1.0, 'Y': 1.0},
#      {'X': 3.6217792853676656e-07, 'Y': 1.0}]},
#    'Id': '8442723f-24a7-4e59-8892-6d9d2ba13a09',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['a97ea69a-9ca1-4016-8d04-c4f0dc17f1f6',
#       '7f699814-2a98-4f90-ba66-48996f3e92b3',
#       'de4c7f82-0ebc-4633-8227-bda91814db0b',
#       '3558d0e4-0271-4a76-a6a2-01387625bc75',
#       '3abb4177-4a24-4f1c-98e1-39f0a7b325e1',
#       '7df3cb05-de16-42ef-b1e7-a766beb4d2e6',
#       '0bfad731-4a5a-49fa-8df5-5bf7bb0c104c',
#       '96daeebb-d56f-4623-8bd2-7e8db531a298',
#       'e208ccdd-422c-4a9e-996d-e367d6f2efce',
#       '352cbf9a-18cc-4a80-b61f-6bf71b245671',
#       '89ed9260-42ca-4dc1-bf34-00a10253639f',
#       '012ee8a3-3de1-4e70-b24a-f54abe83c7af',
#       '79855560-e811-4544-ac21-5ec7948072e6',
#       '2419fa94-3e36-4f0f-8c61-f308de04f899',
#       'a869b32d-2b16-4200-b00f-8b114d2b1b51',
#       'e976de21-06ed-408a-ab6f-d760ba10f957',
#       'b2999de0-3a40-4923-99d6-468458797b95',
#       'b1403781-78dd-4b25-9d40-ddadfec360f2',
#       'bcbd1b4e-b3f7-406c-b791-97a8acc986ac',
}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 88.00227355957031,
#    'Text': '101, 102. 107, 108, 109, 1st Floor. Agarwal Tower, Pkt. O & P Mkt. Dilshad Garden, Delhi-95 Ph.:',
#    'Geometry': {'BoundingBox': {'Width': 0.6438423991203308,
#      'Height': 0.011633985675871372,
#      'Left': 0.14130522310733795,
#      'Top': 0.08067949116230011},
#     'Polygon': [{'X': 0.14130522310733795, 'Y': 0.08097933232784271},
#      {'X': 0.7851366400718689, 'Y': 0.08067949116230011},
#      {'X': 0.7851476073265076, 'Y': 0.09201592206954956},
#      {'X': 0.14131194353103638, 'Y': 0.09231347590684891}]},
#    'Id': '3abb4177-4a24-4f1c-98e1-39f0a7b325e1',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['419f7484-bc2e-44a9-b131-2e29a19a1477',
#       '26cd0334-6186-48a7-86b7-418e265695ff',
#       'e454f396-7b3a-4a45-815a-eba8dcd64e99',
#       '577cb7ef-a5e4-4019-a6b6-361df201a56e',
#       '164383a8-25e1-455d-93a2-61e8d372f093',
#       '098deb7f-1c1b-4a0d-9b60-31482bf973ea',
#       '41bc1886-9007-4c64-9e50-68a59ee88d05',
#       '362b6fb9-7ad3-4979-bc28-9b34ff8d551d',
#       '54567dda-702c-4f13-9fb1-c0839d271289',
#       '06d5abc2-cfbe-49a7-b6b2-78f71b1bc06a',
#       '0ad2f1a6-a6bd-4249-83c2-84a17d43db21',
#       'b38e827a-7c2b-46e7-9de1-7f5b5d8bca34',
#       'e23b7894-d1e1-40a9-90f9-560d4bddc715',
#       '711f9a91-3300-4842-8cbe-76327a8684b8',
#       '95612e81-b4a7-458c-a099-a2dbc6d068da',
#       '84fc905a-805f-413c-a130-ddf9fa7a4d86',
#       '9b52e0ba-d15e-46a7-aaa7-1b02ec9d6e59',
#       'c24901d6-a463-4a29-a097-bf3cf04bcfcd']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.6986312866211,
#    'Text': 'SARVODAYA HOSPITAL',
#    'Geometry': {'BoundingBox': {'Width': 0.24700812995433807,
#      'Height': 0.0128213781863451,
#      'Left': 0.07847139984369278,
#      'Top': 0.10349974781274796},
#     'Polygon': [{'X': 0.07847139984369278, 'Y': 0.10361303389072418},
#      {'X': 0.32547062635421753, 'Y': 0.10349974781274796},
#      {'X': 0.32547953724861145, 'Y': 0.11620882898569107},
#      {'X': 0.07847847044467926, 'Y': 0.1163211315870285}]},
#    'Id': '7df3cb05-de16-42ef-b1e7-a766beb4d2e6',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['93554d5b-970d-4d25-8199-784fe758533c',
#       'd49b7c74-6573-4cd1-8b3f-050312cf26f1']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.09135437011719,
#    'Text': 'Dr. (Capt) Atul Kapila (Retd.) MD Path',
#    'Geometry': {'BoundingBox': {'Width': 0.2465345412492752,
#      'Height': 0.013681206852197647,
#      'Left': 0.37654832005500793,
#      'Top': 0.10236301273107529},
#     'Polygon': [{'X': 0.37654832005500793, 'Y': 0.10247614979743958},
#      {'X': 0.623071014881134, 'Y': 0.10236301273107529},
#      {'X': 0.6230828762054443, 'Y': 0.11593212187290192},
#      {'X': 0.37655821442604065, 'Y': 0.11604421585798264}]},
#    'Id': '0bfad731-4a5a-49fa-8df5-5bf7bb0c104c',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['07f22e37-d261-42a0-8ae3-6c740b777156',
#       '45122fcd-5d68-4715-9741-a0198587ebb4',
#       'da2c0259-ed27-41cf-a364-d347fc76f6a4',
#       'f137b9ea-5fe1-4395-b1ea-0a4de9b36441',
#       '657277d1-5eb1-4af0-86a6-64d2fe90d40e',
#       'e3fd83d4-2dbd-4061-a685-c20d57ada044',
#       'b0358b5c-f286-4379-9b39-2d433593025b']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 94.12788391113281,
#    'Text': 'KJ-7, Kavi Nagar, Ghaziabad (U.P.)',
#    'Geometry': {'BoundingBox': {'Width': 0.19680705666542053,
#      'Height': 0.01133529283106327,
#      'Left': 0.07747993618249893,
#      'Top': 0.1215381994843483},
#     'Polygon': [{'X': 0.07747993618249893, 'Y': 0.12162734568119049},
#      {'X': 0.2742794454097748, 'Y': 0.1215381994843483},
#      {'X': 0.27428698539733887, 'Y': 0.13278503715991974},
#      {'X': 0.07748618721961975, 'Y': 0.13287349045276642}]},
#    'Id': '96daeebb-d56f-4623-8bd2-7e8db531a298',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['54d5de0e-a385-40ad-a920-7d4a2881df42',
#       '27ee9097-cdc7-4f1e-8a6d-31ff5bcb0a91',
#       '3dded99f-5cd9-446d-a1b7-a543f8bcb06a',
#       '65e6af88-55ea-4e50-a4da-c59d62608416',
#       'be42e010-2d95-4cde-badb-817cdf94392f']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 90.50751495361328,
#    'Text': 'Regn No. MCI 3456',
#    'Geometry': {'BoundingBox': {'Width': 0.11374607682228088,
#      'Height': 0.00980656873434782,
#      'Left': 0.4429166913032532,
#      'Top': 0.11813274770975113},
#     'Polygon': [{'X': 0.4429166913032532, 'Y': 0.11818438768386841},
#      {'X': 0.5566546320915222, 'Y': 0.11813274770975113},
#      {'X': 0.5566627383232117, 'Y': 0.127888023853302},
#      {'X': 0.4429241716861725, 'Y': 0.12793931365013123}]},
#    'Id': 'e208ccdd-422c-4a9e-996d-e367d6f2efce',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['59b117c5-9f9d-4ad5-a3b1-37b7df7af4cf',
#       'd030b13a-9aa4-4ed0-b912-52c07610dc3d',
#       '3f1e668a-4f38-43f7-92fe-83eeeb8f4f32',
#       'a1e34bbc-831f-42c5-be10-c3f6341c2431']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 96.54625701904297,
#    'Text': 'Investigation',
#    'Geometry': {'BoundingBox': {'Width': 0.10096529871225357,
#      'Height': 0.010750619694590569,
#      'Left': 0.07891504466533661,
#      'Top': 0.29818159341812134},
#     'Polygon': [{'X': 0.07891504466533661, 'Y': 0.29822173714637756},
#      {'X': 0.1798737496137619, 'Y': 0.29818159341812134},
#      {'X': 0.17988033592700958, 'Y': 0.3088924288749695},
#      {'X': 0.07892100512981415, 'Y': 0.30893221497535706}]},
#    'Id': '352cbf9a-18cc-4a80-b61f-6bf71b245671',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['d83e8ee0-538a-4d51-b8d4-95b0eab88abb']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.7288589477539,
#    'Text': 'Observed Value',
#    'Geometry': {'BoundingBox': {'Width': 0.12428147345781326,
#      'Height': 0.00912017934024334,
#      'Left': 0.40927058458328247,
#      'Top': 0.29951784014701843},
#     'Polygon': [{'X': 0.40927058458328247, 'Y': 0.29956719279289246},
#      {'X': 0.5335446000099182, 'Y': 0.29951784014701843},
#      {'X': 0.5335520505905151, 'Y': 0.30858901143074036},
#      {'X': 0.40927737951278687, 'Y': 0.3086380064487457}]},
#    'Id': '89ed9260-42ca-4dc1-bf34-00a10253639f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['f527ef0f-7723-4600-bda0-1920f4ac3576',
#       'd0f243ca-3eb1-46f3-bbae-5b22cf426252']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.72212982177734,
#    'Text': 'Unit',
#    'Geometry': {'BoundingBox': {'Width': 0.03138970956206322,
#      'Height': 0.009236326441168785,
#      'Left': 0.592383623123169,
#      'Top': 0.30026325583457947},
#     'Polygon': [{'X': 0.592383623123169, 'Y': 0.3002757132053375},
#      {'X': 0.6237652897834778, 'Y': 0.30026325583457947},
#      {'X': 0.6237733364105225, 'Y': 0.3094872236251831},
#      {'X': 0.5923914909362793, 'Y': 0.3094995617866516}]},
#    'Id': '012ee8a3-3de1-4e70-b24a-f54abe83c7af',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['d80bb19c-8738-49bd-8d2a-efa8de055526']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 90.7203598022461,
#    'Text': 'Biological Ref Interval',
#    'Geometry': {'BoundingBox': {'Width': 0.1722872406244278,
#      'Height': 0.010758455842733383,
#      'Left': 0.7176083326339722,
#      'Top': 0.30104395747184753},
#     'Polygon': [{'X': 0.7176083326339722, 'Y': 0.3011122941970825},
#      {'X': 0.8898845911026001, 'Y': 0.30104395747184753},
#      {'X': 0.8898955583572388, 'Y': 0.311734676361084},
#      {'X': 0.7176182866096497, 'Y': 0.3118024170398712}]},
#    'Id': '79855560-e811-4544-ac21-5ec7948072e6',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['66eeb40a-9c64-4411-8406-1cf56fbeb17b',
#       '366d4a67-871d-41ea-9297-272aeef6652e',
#       '6dfb1b15-3435-473b-b3e7-4ab5b7307269']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.41664123535156,
#    'Text': 'BIOCHEMISTRY',
#    'Geometry': {'BoundingBox': {'Width': 0.1258256733417511,
#      'Height': 0.009183790534734726,
#      'Left': 0.4360612630844116,
#      'Top': 0.32678544521331787},
#     'Polygon': [{'X': 0.4360612630844116, 'Y': 0.3268343210220337},
#      {'X': 0.5618792772293091, 'Y': 0.32678544521331787},
#      {'X': 0.5618869662284851, 'Y': 0.33592069149017334},
#      {'X': 0.43606826663017273, 'Y': 0.3359692394733429}]},
#    'Id': '2419fa94-3e36-4f0f-8c61-f308de04f899',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['ffc870f7-c52d-4b4e-ba3c-a260540b807f']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.62788391113281,
#    'Text': 'VER FUNCTION TEST (LFT)',
#    'Geometry': {'BoundingBox': {'Width': 0.22153271734714508,
#      'Height': 0.010594021528959274,
#      'Left': 0.08012156188488007,
#      'Top': 0.34810829162597656},
#     'Polygon': [{'X': 0.08012156188488007, 'Y': 0.34819290041923523},
#      {'X': 0.3016470670700073, 'Y': 0.34810829162597656},
#      {'X': 0.30165427923202515, 'Y': 0.35861843824386597},
#      {'X': 0.08012741804122925, 'Y': 0.35870233178138733}]},
#    'Id': 'a869b32d-2b16-4200-b00f-8b114d2b1b51',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': 
}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 95.42359924316406,
#    'Text': 'CONJUGATED (D. BILIRUBIN)',
#    'Geometry': {'BoundingBox': {'Width': 0.20830343663692474,
#      'Height': 0.010443370789289474,
#      'Left': 0.06809215247631073,
#      'Top': 0.3962434232234955},
#     'Polygon': [{'X': 0.06809215247631073, 'Y': 0.39631983637809753},
#      {'X': 0.27638861536979675, 'Y': 0.3962434232234955},
#      {'X': 0.2763955891132355, 'Y': 0.40661105513572693},
#      {'X': 0.06809785962104797, 'Y': 0.40668681263923645}]},
#    'Id': 'a6f38ea5-33c9-4d3e-833b-9e44e43028a9',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['41684514-6d83-43d2-be25-0bd300a91e0c',
#       'e59803b4-e184-4511-a367-ca35f2f79967',
#       '4b13f69d-4fe7-4f41-9f42-a20f6e3b3ce9']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 94.0261459350586,
#    'Text': '7.79 H',
#    'Geometry': {'BoundingBox': {'Width': 0.04300607740879059,
#      'Height': 0.008274499326944351,
#      'Left': 0.44729653000831604,
#      'Top': 0.39752066135406494},
#     'Polygon': [{'X': 0.44729653000831604, 'Y': 0.39753642678260803},
#      {'X': 0.49029600620269775, 'Y': 0.39752066135406494},
#      {'X': 0.49030259251594543, 'Y': 0.40577954053878784},
#      {'X': 0.447302907705307, 'Y': 0.4057951867580414}]},
#    'Id': '6bb8f39d-8af7-4ac4-bfa7-345d5061400c',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['ff518031-13ed-422a-8afe-3a90bc6929ae',
#       'a5c5c106-128b-4e7f-a266-6fcc310e6cf9']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 96.91803741455078,
#    'Text': 'mg/dL',
#    'Geometry': {'BoundingBox': {'Width': 0.04113822057843208,
#      'Height': 0.009949509054422379,
#      'Left': 0.58548903465271,
#      'Top': 0.39820459485054016},
#     'Polygon': [{'X': 0.58548903465271, 'Y': 0.39821964502334595},
#      {'X': 0.6266185641288757, 'Y': 0.39820459485054016},
#      {'X': 0.6266272664070129, 'Y': 0.408139169216156},
#      {'X': 0.5854974985122681, 'Y': 0.40815410017967224}]},
#    'Id': 'a8ece4ae-00a6-4031-a729-1158f6de576d',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['94edccb4-7577-4abb-aca4-87597cac1583']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 62.4154167175293,
#    'Text': '0.00 0,30',
#    'Geometry': {'BoundingBox': {'Width': 0.07106456905603409,
#      'Height': 0.00831026490777731,
#      'Left': 0.7679369449615479,
#      'Top': 0.39893636107444763},
#     'Polygon': [{'X': 0.7679369449615479, 'Y': 0.3989623486995697},
#      {'X': 0.8389932513237, 'Y': 0.39893636107444763},
#      {'X': 0.8390015363693237, 'Y': 0.4072208106517792},
#      {'X': 0.767944872379303, 'Y': 0.4072466194629669}]},
#    'Id': 'fcb24275-cd4d-4a2e-be2f-e34aeb0bef8a',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['88e968b7-be7b-4200-94a8-8558250837e5',
#       '0fd83ba4-48e9-4314-a7fd-ddd3c467f3d8']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 95.77185821533203,
#    'Text': 'UNCONJUGATED (I.D.BILIRUBIN)',
#    'Geometry': {'BoundingBox': {'Width': 0.23426330089569092,
#      'Height': 0.010261227376759052,
#      'Left': 0.06799548119306564,
#      'Top': 0.4249313473701477},
#     'Polygon': [{'X': 0.06799548119306564, 'Y': 0.4250151813030243},
#      {'X': 0.30225178599357605, 'Y': 0.4249313473701477},
#      {'X': 0.30225878953933716, 'Y': 0.4351094961166382},
#      {'X': 0.06800107657909393, 'Y': 0.4351925849914551}]},
#    'Id': 'a7ed1e03-2a5f-457d-890b-82f3506fc309',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': 
}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 65.35308837890625,
#    'Text': 'IU/L',
#    'Geometry': {'BoundingBox': {'Width': 0.025691239163279533,
#      'Height': 0.008256695233285427,
#      'Left': 0.5920779705047607,
#      'Top': 0.484175443649292},
#     'Polygon': [{'X': 0.5920779705047607, 'Y': 0.4841841757297516},
#      {'X': 0.61776202917099, 'Y': 0.484175443649292},
#      {'X': 0.6177692413330078, 'Y': 0.49242350459098816},
#      {'X': 0.592085063457489, 'Y': 0.4924321472644806}]},
#    'Id': 'ec1a6b6d-2764-48ee-aade-6d1d074b6bf0',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['057dabda-dc2e-497e-ac68-3e613f82e8e6']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 82.26102447509766,
#    'Text': '0.00 49.00',
#    'Geometry': {'BoundingBox': {'Width': 0.07953187823295593,
#      'Height': 0.007838370278477669,
#      'Left': 0.7625018954277039,
#      'Top': 0.48539894819259644},
#     'Polygon': [{'X': 0.7625018954277039, 'Y': 0.4854258894920349},
#      {'X': 0.8420259952545166, 'Y': 0.48539894819259644},
#      {'X': 0.8420338034629822, 'Y': 0.4932105541229248},
#      {'X': 0.7625093460083008, 'Y': 0.49323731660842896}]},
#    'Id': '4c963168-0f60-4f7f-a85f-2593fb6b8f7f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['1bebbccc-5ea3-48d0-a82f-2feebd099062',
#       '963f78d2-c747-43c1-a763-06f683bb7cb6']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.97904968261719,
#    'Text': 'ALKALINE PHOSPHATASE',
#    'Geometry': {'BoundingBox': {'Width': 0.1874627321958542,
#      'Height': 0.008655278943479061,
#      'Left': 0.06610593944787979,
#      'Top': 0.5111840963363647},
#     'Polygon': [{'X': 0.06610593944787979, 'Y': 0.5112461447715759},
#      {'X': 0.2535630166530609, 'Y': 0.5111840963363647},
#      {'X': 0.2535686790943146, 'Y': 0.5197778940200806},
#      {'X': 0.06611065566539764, 'Y': 0.5198394060134888}]},
#    'Id': '35c48cd3-cb6e-419b-96dd-746100192573',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['cbcf96dc-503b-46c0-a7b4-76bb4dd6e73f',
#       '74cc342b-91bf-4b35-a98b-4682f542668c']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.01140594482422,
#    'Text': '396 H',
#    'Geometry': {'BoundingBox': {'Width': 0.039401814341545105,
#      'Height': 0.007952379994094372,
#      'Left': 0.44809624552726746,
#      'Top': 0.5125430822372437},
#     'Polygon': [{'X': 0.44809624552726746, 'Y': 0.5125560760498047},
#      {'X': 0.48749175667762756, 'Y': 0.5125430822372437},
#      {'X': 0.48749807476997375, 'Y': 0.5204825401306152},
#      {'X': 0.4481023848056793, 'Y': 0.5204954743385315}]},
#    'Id': 'fa401e49-40f7-4c7a-b5e0-bebab490c900',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['4802a532-7705-4e52-ac8b-8a2cfd2c9966',
#       'ae0ef64a-a55a-4ef3-b265-449b6a1be70b']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.8728256225586,
#    'Text': 'U/L',
#    'Geometry': {'BoundingBox': {'Width': 0.021395741030573845,
#      'Height': 0.00795380026102066,
#      'Left': 0.5942365527153015,
#      'Top': 0.5131466388702393},
#     'Polygon': [{'X': 0.5942365527153015, 'Y': 0.5131537318229675},
#      {'X': 0.6156253814697266, 'Y': 0.5131466388702393},
#      {'X': 0.6156322956085205, 'Y': 0.5210934281349182},
#      {'X': 0.5942433476448059, 'Y': 0.5211004614830017}]},
#    'Id': 'e364094e-1d5b-4c8f-9dd1-9c40cbc3e597',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': 
}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 75.72119140625,
#    'Text': '6,20 8.00',
#    'Geometry': {'BoundingBox': {'Width': 0.07182913273572922,
#      'Height': 0.008663753047585487,
#      'Left': 0.7657370567321777,
#      'Top': 0.542919933795929},
#     'Polygon': [{'X': 0.7657370567321777, 'Y': 0.542943000793457},
#      {'X': 0.8375575542449951, 'Y': 0.542919933795929},
#      {'X': 0.8375661969184875, 'Y': 0.5515608787536621},
#      {'X': 0.7657453417778015, 'Y': 0.5515837073326111}]},
#    'Id': 'f95c0214-8ebb-4f07-b9d9-fcb51bd80a10',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['279db874-c873-43c9-a77b-5a8e5ab37721',
#       '423d0175-9168-4029-9540-c5d205dc2be1']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 99.48655700683594,
#    'Text': 'ALBUMIN',
#    'Geometry': {'BoundingBox': {'Width': 0.06572981178760529,
#      'Height': 0.008098481222987175,
#      'Left': 0.06515835970640182,
#      'Top': 0.5696672201156616},
#     'Polygon': [{'X': 0.06515835970640182, 'Y': 0.5696877241134644},
#      {'X': 0.13088342547416687, 'Y': 0.5696672201156616},
#      {'X': 0.1308881640434265, 'Y': 0.5777453184127808},
#      {'X': 0.0651627853512764, 'Y': 0.5777656435966492}]},
#    'Id': '8fae3053-5ee5-4c19-b013-d7d71de7cae1',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['1fd62878-780c-4f3c-ac10-f0bedf140ba0']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 87.89096069335938,
#    'Text': '3.7 L',
#    'Geometry': {'BoundingBox': {'Width': 0.03361649811267853,
#      'Height': 0.008237396366894245,
#      'Left': 0.45005813241004944,
#      'Top': 0.5709370374679565},
#     'Polygon': [{'X': 0.45005813241004944, 'Y': 0.570947527885437},
#      {'X': 0.48366808891296387, 'Y': 0.5709370374679565},
#      {'X': 0.4836746156215668, 'Y': 0.5791640281677246},
#      {'X': 0.450064480304718, 'Y': 0.5791744589805603}]},
#    'Id': 'bb46e33e-859c-4fda-b993-710a8a5f8f87',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['7146746d-aba3-4c48-aec5-ce8cc7bed4a2',
#       '33bffb42-ce71-45e5-9a46-66a247d79d09']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 72.4454574584961,
#    'Text': 'gm/dl',
#    'Geometry': {'BoundingBox': {'Width': 0.036310214549303055,
#      'Height': 0.010072307661175728,
#      'Left': 0.5863686203956604,
#      'Top': 0.5714870691299438},
#     'Polygon': [{'X': 0.5863686203956604, 'Y': 0.5714983940124512},
#      {'X': 0.62267005443573, 'Y': 0.5714870691299438},
#      {'X': 0.622678816318512, 'Y': 0.5815481543540955},
#      {'X': 0.5863772034645081, 'Y': 0.5815593600273132}]},
#    'Id': '16f1f855-4582-49b0-a1ca-609bb7193334',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['d14c6703-4f5d-45cc-a3fe-74d088680146']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 76.3161392211914,
#    'Text': '3,80 5.40',
#    'Geometry': {'BoundingBox': {'Width': 0.07093274593353271,
#      'Height': 0.008415911346673965,
#      'Left': 0.7660230994224548,
#      'Top': 0.5722299218177795},
#     'Polygon': [{'X': 0.7660230994224548, 'Y': 0.5722519755363464},
#      {'X': 0.8369474411010742, 'Y': 0.5722299218177795},
#      {'X': 0.8369558453559875, 'Y': 0.5806238651275635},
#      {'X': 0.7660310864448547, 'Y': 0.5806457996368408}]},
#    'Id': '64188d3e-5064-4730-8a85-cee12e08085b',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['c6cbb3e3-d489-42a8-9c92-3da471f238ec',
#       'a26f99f1-ed92-463f-8979-2ea807eaeee7']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98

#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['764b0309-ffe6-495a-a99e-aea3bde40147',
#       'a38db9fc-f9fa-4a38-a0be-d76bfdac9955']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 77.08970642089844,
#    'Text': '1.48',
#    'Geometry': {'BoundingBox': {'Width': 0.027486996725201607,
#      'Height': 0.007999515160918236,
#      'Left': 0.45277535915374756,
#      'Top': 0.6282663345336914},
#     'Polygon': [{'X': 0.45277535915374756, 'Y': 0.6282744407653809},
#      {'X': 0.480256050825119, 'Y': 0.6282663345336914},
#      {'X': 0.4802623689174652, 'Y': 0.6362578272819519},
#      {'X': 0.4527815580368042, 'Y': 0.6362658739089966}]},
#    'Id': '0c78470e-255c-4bce-8aa0-6f49eae16f19',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['fc241860-c760-4855-86aa-c3e9b64fcd9a']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 83.51531219482422,
#    'Text': '1.0 2.0',
#    'Geometry': {'BoundingBox': {'Width': 0.05307178571820259,
#      'Height': 0.007821588777005672,
#      'Left': 0.7747552394866943,
#      'Top': 0.6295326948165894},
#     'Polygon': [{'X': 0.7747552394866943, 'Y': 0.6295482516288757},
#      {'X': 0.827819287776947, 'Y': 0.6295326948165894},
#      {'X': 0.8278270363807678, 'Y': 0.6373388171195984},
#      {'X': 0.774762749671936, 'Y': 0.6373542547225952}]},
#    'Id': '32dd5d13-cdc4-4b34-b54f-2aacf4f5bd2c',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['eb3ba3e2-6435-4566-bd39-5712a6f2a95d',
#       'c18028ab-0d19-43a1-b1a9-bfc50a4af36c']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 97.49932098388672,
#    'Text': 'GAMMAT-GT',
#    'Geometry': {'BoundingBox': {'Width': 0.08861690014600754,
#      'Height': 0.008305172435939312,
#      'Left': 0.06501706689596176,
#      'Top': 0.6553676128387451},
#     'Polygon': [{'X': 0.06501706689596176, 'Y': 0.6553929448127747},
#      {'X': 0.15362900495529175, 'Y': 0.6553676128387451},
#      {'X': 0.1536339670419693, 'Y': 0.6636477112770081},
#      {'X': 0.06502160429954529, 'Y': 0.6636728048324585}]},
#    'Id': '1fc68002-bcaf-4aa0-81ec-883fd210b0b2',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['f5e45b94-1f1c-44ab-8a51-3c1249c25f02']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 98.20377349853516,
#    'Text': '263 H',
#    'Geometry': {'BoundingBox': {'Width': 0.038971930742263794,
#      'Height': 0.008085626177489758,
#      'Left': 0.446059912443161,
#      'Top': 0.656764805316925},
#     'Polygon': [{'X': 0.446059912443161, 'Y': 0.6567758917808533},
#      {'X': 0.48502543568611145, 'Y': 0.656764805316925},
#      {'X': 0.4850318431854248, 'Y': 0.6648394465446472},
#      {'X': 0.44606614112854004, 'Y': 0.6648504137992859}]},
#    'Id': 'ff4cf3bc-1ee3-421e-b3fb-e386d28f0ce0',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['482c50ea-6a85-41ca-a094-2d36c63409f2',
#       '356d43b4-3263-4b8d-85f8-ba6389e6857b']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 97.55426788330078,
#    'Text': 'IU/L',
#    'Geometry': {'BoundingBox': {'Width': 0.026792000979185104,
#      'Height': 0.00792906153947115,
#      'Left': 0.5900943279266357,
#      'Top': 0.6576457619667053},
#     'Polygon': [{'X': 0.5900943279266357, 'Y': 0.6576533913612366},
#      {'X': 0.6168794631958008, 'Y': 0.6576457619667053},
#      {'X': 0.61688631772995, 'Y': 0.6655672192573547},
#      {'X': 0.5901011228561401, 'Y': 0.6655747890472412}]},
#    'Id': 'ed39f896-0f5f-47ec-b575-48b1d74fdc19',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['f5c6a1fa-dbb8-4e2b-99fa-95b40dcdc365']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 83.5901870727539,
#    'Text': '11,00 50.00',
#    'Geometry': {'BoundingBox': {'Width': 0.0864686444401741,
#      'Height': 0.008234991692006588,
#      'Left': 0.7581291794776917,
#      'Top': 0.657992959022522},
#     'Polygon': [{'X': 0.7581291794776917, 'Y': 0.6580175757408142},
#      {'X': 0.8445895910263062, 'Y': 0.657992959022522},
#      {'X': 0.8445978760719299, 'Y': 0.6662035584449768},
#      {'X': 0.758137047290802, 'Y': 0.6662279367446899}]},
#    'Id': 'eda58ceb-c59e-41a4-a7cd-2374a08b35ce',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['fae563dd-29d3-4311-83f7-d4be4e9100db',
#       'd2fdd498-040a-446c-a3ed-c5b9e02cbd5d']}],
#    'Page': 1},
#   {'BlockType': 'LINE',
#    'Confidence': 95.4974594116211,
#    'Text': 'Specimen : SERUM',
#    'Geometry': {'BoundingBox': {'Width': 0.15808692574501038,
#      'Height': 0.011562100611627102,
#      'Left': 0.06448233127593994,
#      'Top': 0.6878909468650818},
#     'Polygon': [{'X': 0.06448233127593994, 'Y': 0.6879345178604126},
#      {'X': 0.22256189584732056, 'Y': 0.6878909468650818},
#      {'X': 0.2225692719221115, 'Y': 0.699410080909729},
#      {'X': 0.06448864936828613, 'Y': 0.6994530558586121}]},
#    'Id': '475f25f5-04c7-4da8-9cee-6201b6a3d468',
# ...
#    'Text': 'P',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.008408958092331886,
#      'Height': 0.007926877588033676,
#      'Left': 0.5240011811256409,
#      'Top': 0.08222648501396179},
#     'Polygon': [{'X': 0.5240011811256409, 'Y': 0.08222648501396179},
#      {'X': 0.5323975682258606, 'Y': 0.08223150670528412},
#      {'X': 0.5324101448059082, 'Y': 0.09015336632728577},
#      {'X': 0.5240136384963989, 'Y': 0.09014830738306046}]},
#    'Id': 'ad6e491a-9fe7-4029-b441-ad5463a4ac22',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 98.1023941040039,
#    'Text': 'Mkt.',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.027840977534651756,
#      'Height': 0.008143126033246517,
#      'Left': 0.5374637246131897,
#      'Top': 0.08195873349905014},
#     'Polygon': [{'X': 0.5374637246131897, 'Y': 0.08195873349905014},
#      {'X': 0.5652915835380554, 'Y': 0.08197536319494247},
#      {'X': 0.565304696559906, 'Y': 0.09010185301303864},
#      {'X': 0.5374765992164612, 'Y': 0.09008509665727615}]},
#    'Id': '79342420-6574-4cbc-b19b-069d1a93794b',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.83708190917969,
#    'Text': 'Dilshad',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.05143386870622635,
#      'Height': 0.008437290787696838,
#      'Left': 0.570105254650116,
#      'Top': 0.0818614661693573},
#     'Polygon': [{'X': 0.570105254650116, 'Y': 0.0818614661693573},
#      {'X': 0.6215251684188843, 'Y': 0.08189219236373901},
#      {'X': 0.6215391159057617, 'Y': 0.09029875695705414},
#      {'X': 0.5701188445091248, 'Y': 0.09026777744293213}]},
#    'Id': '432a354a-ae1f-4329-aa68-c9b571143f3a',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.28308868408203,
#    'Text': 'Ga',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0

#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.02657361514866352,
#      'Height': 0.01073900144547224,
#      'Left': 0.4282435178756714,
#      'Top': 0.10203637927770615},
#     'Polygon': [{'X': 0.4282435178756714, 'Y': 0.10203637927770615},
#      {'X': 0.45480096340179443, 'Y': 0.10205255448818207},
#      {'X': 0.45481714606285095, 'Y': 0.11277537792921066},
#      {'X': 0.4282594621181488, 'Y': 0.11275903880596161}]},
#    'Id': 'b3e8d708-12df-463e-a24f-d5aad0840b82',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.60897064208984,
#    'Text': 'Kapila',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.04109807312488556,
#      'Height': 0.012826234102249146,
#      'Left': 0.45984911918640137,
#      'Top': 0.10211244225502014},
#     'Polygon': [{'X': 0.45984911918640137, 'Y': 0.10211244225502014},
#      {'X': 0.5009273290634155, 'Y': 0.10213746875524521},
#      {'X': 0.5009471774101257, 'Y': 0.11493867635726929},
#      {'X': 0.45986849069595337, 'Y': 0.11491335928440094}]},
#    'Id': '042296bf-67f9-4ba6-b49e-2936e78573b3',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.71434783935547,
#    'Text': '(Retd.)',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.042652908712625504,
#      'Height': 0.012734660878777504,
#      'Left': 0.5057036280632019,
#      'Top': 0.10228303074836731},
#     'Polygon': [{'X': 0.5057036280632019, 'Y': 0.10228303074836731},
#      {'X': 0.5483362674713135, 'Y': 0.10230900347232819},
#      {'X': 0.5483565330505371, 'Y': 0.11501769721508026},
#      {'X': 0.5057234168052673, 'Y': 0.11499141901731491}]},
#    'Id': 'f9cfd9b5-8e45-4c96-8333-f9d75bb534b9',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.85924530029297,
#    'Text': 'MD',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.020259691402316093,
#      'Height': 0.010005573742091656,
#      'Left': 0.5540851354598999,
#      'Top': 0.10263936966657639},
#     'Polygon': [{'X': 0.5540851354598999, 'Y': 0.10263936966657639},
#      {'X': 0.574328601360321, 'Y': 0.1026517003774643},
#      {'X': 0.5743448138237, 'Y': 0.11264494061470032},
#      {'X': 0.5541011095046997, 'Y': 0.11263249069452286}]},
#    'Id': '5455bfbb-8552-48b6-b8f2-630ec9b4dafa',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.92391204833984,
#    'Text': 'Path',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.028582455590367317,
#      'Height': 0.009962822310626507,
#      'Left': 0.5798213481903076,
#      'Top': 0.10270417481660843},
#     'Polygon': [{'X': 0.5798213481903076, 'Y': 0.10270417481660843},
#      {'X': 0.6083874106407166, 'Y': 0.10272158682346344},
#      {'X': 0.6084038019180298, 'Y': 0.11266699433326721},
#      {'X': 0.5798375010490417, 'Y': 0.11264942586421967}]},
#    'Id': '29f39a4e-bc06-4221-a51c-613ecfc88277',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 97.71475219726562,
#    'Text': 'KJ-7,',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.02839944325387478,
#      'Height': 0.00974117498844862,
#      'Left': 0.06317640095949173,
#      'Top': 0.11915051937103271},
#     'Polygon': [{'X': 0.06317640095949173, 'Y': 0.11915051937103271},
#      {'X': 0.09156443178653717, 'Y': 0.11916808784008026},
#      {'X': 0.09157584607601166, 'Y': 0.1288916915655136},
#      {'X': 0.06318756192922592, 'Y': 0.12887397408485413}]},
#    'Id': '07204ae0-5731-47c0-b3b5-7abc908843ca',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.09710693359375,
#    'Text': 'Kavi',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.023877402767539024,
#      'Height': 0.008516611531376839,
#      'Left': 0.09743210673332214,
#      'Top': 0.11934084445238113},
#     'Polygon': [{'X': 0.09743210673332214, 'Y': 0.11934084445238113},
#      {'X': 0.12129929661750793, 'Y': 0.11935561895370483},
#      {'X': 0.12130951136350632, 'Y': 0.12785746157169342},
#      {'X': 0.0974421352148056, 'Y': 0.12784257531166077}]},
#    'Id': '25dc02a9-b456-45df-94ae-9ea62fcf6a51',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 97.86933135986328,
#    'Text': 'Nagar,',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.03531700000166893,
#      'Height': 0.010606263764202595,
#      'Left': 0.12616021931171417,
#      'Top': 0.11960349977016449},
#     'Polygon': [{'X': 0.12616021931171417, 'Y': 0.11960349977016449},
#      {'X': 0.16146411001682281, 'Y': 0.11962535977363586},
#      {'X': 0.1614772081375122, 'Y': 0.1302097588777542},
#      {'X': 0.1261729747056961, 'Y': 0.13018769025802612}]},
#    'Id': 'ba73e46b-befa-4469-adb6-caf07af6de49',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.36978912353516,
#    'Text': 'Ghaziabad',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.05703630670905113,
#      'Height': 0.009295839816331863,
#      'Left': 0.16773848235607147,
#      'Top': 0.11910127103328705},
#     'Polygon': [{'X': 0.16773848235607147, 'Y': 0.11910127103328705},
#      {'X': 0.22476276755332947, 'Y': 0.11913656443357468},
#      {'X': 0.2247747927904129, 'Y': 0.1283971071243286},
#      {'X': 0.16775000095367432, 'Y': 0.1283615231513977}]},
#    'Id': 'ec717ad7-84f8-4481-b643-eba3a4b33cde',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 94.15099334716797,
#    'Text': '(U.P.)',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.02988595888018608,
#      'Height': 0.010619696229696274,
#      'Left': 0.23000942170619965,
#      'Top': 0.11894819140434265},
#     'Polygon': [{'X': 0.23000942170619965, 'Y': 0.11894819140434265},
#      {'X': 0.25988128781318665, 'Y': 0.11896666884422302},
#      {'X': 0.259895384311676, 'Y': 0.12956789135932922},
#      {'X': 0.23002322018146515, 'Y': 0.12954922020435333}]},
#    'Id': '00536c75-f7be-455b-8c33-d5f1d9232f62',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 98.41022491455078,
#    'Text': 'Regn',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.029551886022090912,
#      'Height': 0.010100211948156357,
#      'Left': 0.42837992310523987,
#      'Top': 0.11754736304283142},
#     'Polygon': [{'X': 0.42837992310523987, 'Y': 0.11754736304283142},
#      {'X': 0.4579165577888489, 'Y': 0.11756560951471329},
#      {'X': 0.457931786775589, 'Y': 0.12764757871627808},
#      {'X': 0.4283948838710785, 'Y': 0.12762916088104248}]},
#    'Id': '7c32163b-8ad6-4935-a565-9c145ba54720',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 87.92436981201172,
#    'Text': 'No.',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.01899709366261959,
#      'Height': 0.008284490555524826,
#      'Left': 0.462889701128006,
#      'Top': 0.11770609766244888},
#     'Polygon': [{'X': 0.462889701128006, 'Y': 0.11770609766244888},
#      {'X': 0.48187410831451416, 'Y': 0.11771782487630844},
#      {'X': 0.4818868041038513, 'Y': 0.1259905844926834},
#      {'X': 0.4629022479057312, 'Y': 0.1259787678718567}]},
#    'Id': 'bd34a1a4-121f-47ca-9c5a-d1959bfb9e9e',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 97.73534393310547,
#    'Text': 'MCI',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.022643622010946274,
#      'Height': 0.008169160224497318,
#      'Left': 0.48709073662757874,
#      'Top': 0.1177622601389885},
#     'Polygon': [{'X': 0.48709073662757874, 'Y': 0.1177622601389885},
#      {'X': 0.5097216367721558, 'Y': 0.11777624487876892},
#      {'X': 0.5097343921661377, 'Y': 0.12593142688274384},
#      {'X': 0.48710331320762634, 'Y': 0.12591733038425446}]},
#    'Id': '9596445c-d779-49b8-8b57-38b7a5a5a39b',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 98.29671478271484,
#    'Text': '3456',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.027846476063132286,
#      'Height': 0.008145727217197418,
#      'Left': 0.514530599117279,
#      'Top': 0.11780919879674911},
#     'Polygon': [{'X': 0.514530599117279, 'Y': 0.11780919879674911},
#      {'X': 0.5423641800880432, 'Y': 0.11782640218734741},
#      {'X': 0.5423771142959595, 'Y': 0.12595492601394653},
#      {'X': 0.514543354511261, 'Y': 0.1259375959634781}]},
#    'Id': '3f59f093-be2f-4a8b-9942-52fa1cbade26',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 78.51983642578125,
#    'Text': 'Sri',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.02085830457508564,
#      'Height': 0.009221433661878109,
#      'Left': 0.4536249041557312,
#      'Top': 0.17683082818984985},
#     'Polygon': [{'X': 0.4536249041557312, 'Y': 0.17683082818984985},
#      {'X': 0.4744691252708435, 'Y': 0.17684440314769745},
#      {'X': 0.4744831919670105, 'Y': 0.18605226278305054},
#      {'X': 0.45363879203796387, 'Y': 0.1860385686159134}]},
#    'Id': '951874ef-9251-49ad-82c7-57eaf9d25fc2',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.55879211425781,
#    'Text': 'No.',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.024973055347800255,
#      'Height': 0.009078877978026867,
#      'Left': 0.4813553988933563,
#      'Top': 0.17723578214645386},
#     'Polygon': [{'X': 0.4813553988933563, 'Y': 0.17723578214645386},
#      {'X': 0.5063143372535706, 'Y': 0.17725203931331635},
#      {'X': 0.5063284635543823, 'Y': 0.186314657330513},
#      {'X': 0.4813693165779114, 'Y': 0.18629826605319977}]},
#    'Id': '5bbb3f19-fef9-47c0-a9d9-cceae031fa44',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 98.70694732666016,
#    'Text': '1019',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.03561517223715782,
#      'Height': 0.009149295277893543,
#      'Left': 0.5187464952468872,
#      'Top': 0.17770329117774963},
#     'Polygon': [{'X': 0.5187464952468872, 'Y': 0.17770329117774963},
#      {'X': 0.554347038269043, 'Y': 0.17772649228572845},
#      {'X': 0.5543616414070129, 'Y': 0.1868525892496109},
#      {'X': 0.5187608003616333, 'Y': 0.18682919442653656}]},
#    'Id': '158508be-47a0-4828-b18f-fc73adf14a1c',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.73268127441406,
#    'Text': 'RECEIPT',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.07224701344966888,
#      'Height': 0.00897402223199606,
#      'Left': 0.6959353685379028,
#      'Top': 0.17956210672855377},
#     'Polygon': [{'X': 0.6959353685379028, 'Y': 0.17956210672855377},
#      {'X': 0.7681663036346436, 'Y': 0.1796092540025711},
#      {'X': 0.7681823968887329, 'Y': 0.1885361224412918},
#      {'X': 0.6959508061408997, 'Y': 0.18848861753940582}]},
#    'Id': '640377dd-7fb8-4270-99dd-b2b76bc63a07',
#    'Page': 3},
#   {'BlockType': 'WORD',
#    'Confidence': 99.74855041503906,
#    'Text': 'ID',
#    'TextType': 'PRINTED',
#    'Geometry': {'BoundingBox': {'Width': 0.014689351432025433,
#      'Height': 0.00853731483221054,
#      'Left': 0.773737370967865,
#      'Top': 0.18024297058582306},
#     'Polygon': [{'X': 0.773737370967865, 'Y': 0.18024297058582306},
#      {'X': 0.7884112596511841, 'Y': 0.1802525520324707},
#      {'X': 0.7884267568588257, 'Y': 0.188780277967453},
#      {'X': 0.7737528085708618, 'Y': 0.1887706220149994}]},
#    'Id': 'b8717222-5fc1-4281-b4bf-db694de266fe',
#    'Page': 3},
#   ...],
#  'AnalyzeDocumentModelVersion': '1.0',
#  'ResponseMetadata': {'RequestId': '15cf5c4a-394c-4857-95c0-eff22d0b36d5',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '15cf5c4a-394c-4857-95c0-eff22d0b36d5',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '576735',
#    'date': 'Tue, 17 Jun 2025 22:29:14 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# #### Convert textract response into markdown file

# %%
markdown_response = textractor.parse_textract_response(textract_response = textract_response)

# %%
print(markdown_response)
# Out:
# --- Page 1---
# T
#
#
# ISO:9001-2008
#
# # Diagnostic Point Pathology Labs
#
# EQUIPPED WITH COMPUTERISED AUTO CHEMISTRY, BLOOD GAS & HAEMATOLOGY ANALYSERS
#
# 101, 102. 107, 108, 109, 1st Floor. Agarwal & P Mkt. Dilshad Garden, Delhi-95 Tower, Pkt. O Ph.:
#
# SARVODAYA HOSPITAL KJ-7, Kavi Nagar, Ghaziabad (U.P.)
#
#
# Dr. (Capt) Atul Kapila (Retd.) MD Path MCI 3456
#
# Regn No.
#
#
#
#
# | Investigation                | Observed Value    | Unit    | Biological Ref Interval    |
# |------------------------------|-------------------|---------|----------------------------|
# | BIOCHEMISTRY                 |                   |         |                            |
# | VER FUNCTION TEST (LFT)      |                   |         |                            |
# | BILIRUBIN TOTAL              | 9.42 H            | mg/dl   | 0.30 1.20                  |
# | CONJUGATED (D. BILIRUBIN)    | 7.79 H            | mg/dL   | 0.00 0,30                  |
# | UNCONJUGATED (I.D.BILIRUBIN) | 1.63 H            | mg/dl   | 0.00 0,70                  |
# | SGOT                         | 162 H             | IU/L    | 0,00 46.00                 |
# | SGPT                         | 86 H              | IU/L    | 0.00 49.00                 |
# | ALKALINE PHOSPHATASE         | 396 H             | U/L     | 42.00 128.00               |
# | TOTAL PROTEIN                | 6.2               | gm/dl   | 6,20 8.00                  |
# | ALBUMIN                      | 3.7 L             | gm/dl   | 3,80 5.40                  |
# | GLOBULIN                     | 2.5               | gm/dl   | 1.50 3.60                  |
# | A/G RATIO                    | 1.48              |         | 1.0 2.0                    |
# | GAMMAT-GT                    | 263 H             | IU/L    | 11,00 50.00                |
#
#
#
#
# Specimen : SERUM
#
#
# ** END OF REPORT **
#
# T'"
#
#
#
# Dr. ATU A
#
#
#  NOTE : ABOVE MENTIONED FINDINGS ARE A PROFESSIONAL AND NOT A FINAL DIAGNOSIS, ALL LABORATORY TESTS & OTHER DISCREPANCIES, IF ANY. NECESSITATE REVIEW/REPEAT OF THE TESTS.
#
#
# FACILITIES : FOR HORMONES ASSAYS, FNAC, HISTOPATHOLOGY, BONE MARROW ASPIRATION & BIOPSY WITH MICRO PHOTOGRAPHS
#
#
#
# INVESTIGATION RESULTS ARE TO BE CORELATED CLINIC-PATHOLOGICALLY.
#
#
#
# NOT VAILD FOR
#
#
#
# LEGAL PURPOSE
#
#
#
# CLINICAL CORELATION IS MANDATORY
#
#
# P
#
#
#  ISO : 9001-2008
#
# # Diagnostic Point Pathology Labs
#
# EQUIPPED WITH COMPUTERISED AUTO CHEMISTRY, BLOOD GAS & HAEMATOLOGY ANALYSERS
#
#  101, 102, 107, 108, 109, 1st Floor, Agarwal Tower, Pkt. O & P Mkt.
#
#
# Dilshad Garden, Delhi-95 Ph.:
#
#
# SARVODAYA HOSPITAL KJ-7, Kavi Nagar, Ghaziabad (U.P.)
#
# Dr. (Capt) Atul Kapila (Retd.) MD Path
#
#
# Regn No. MCI 3456
#
#
#
#
#
#
#
# :
#
# Patient
#
# Referred VERMA
#
# Lab Serial No: 07
#
# Ward No : SP 25
#
# CR / UHD No : / 391503
# 0223
#
#
#
#
#  Receiving 6:00:30AM Reporting Date : 8:29:07AM
#
#
# Date TAT 2 Hours 29 Minute
#
#
#
#
# | Investigation                  | Observed Value    | Unit      | Biological Ref Interval    |
# |--------------------------------|-------------------|-----------|----------------------------|
# | HEMATOLOGY                     |                   |           |                            |
# | PT ( PROTHROMBIN TIME          |                   |           |                            |
# | NORMAL CONTROL VALUE           | 13,0              | second(s) |                            |
# | PATIENT VALUE                  | 17.5              | second(s) |                            |
# | International Normalized Ratio | 1.37              |           |                            |
# PT PLASMA
#
#
#
#
# Specimen :
#
#
# Comment :
#
# 1. INR is the parameter of choice in monitoring adequacy of oral anticoagulant therapy. Appropriate therapeutic range varies with the disease and treatment intensity
# 2. Prolonged INR suggests potential bleeding disorder / bleeding complications
# 3. Results should be clinically correlated
# 4. Test conducted on Citrated plasma
#
# RecommendedTherapeutio range for Oral Anticoagulant therapy INR 2.0-3.0 Treatment of Venous thrombosis & Pulmonary embolism- Prophylaxis of Venous thrombosis (High risk surgery) Prevention of systemic embolism in tissue heart valves, AMI, Valvular heart disease & Atrial fibrillation- Bileaflet mechanical valve in aortic position INR 2.5-3.5: Mechanical prosthetic valves Comments: Systemic recurrent emboli Prothrombin time measures the extrinsic coagulation pathway which consists of activated Factor VII (Vlla), Tissue factor and Proteins of the common pathway (Factors X, V, Il & Fibrinogen). This assay is used to control long term oral anticoagulant therapy, evaluation of liver function & to evaluate coagulation disorders specially factors involved in the extrinsic pathway like Factors V, VII, X, Prothrombin & Fibrinogen.
#
# ** END OF REPORT **
#
#
#
#
#
#
# Page 1 of 1
#
#
#
# FACILITIES FOR HORMONES ASSAYS, FNAC, HISTOPATHOLOGY, BONE MARROW ASPIRATION & BIOPSY WITH MICRO PHOTOGRAPHS.
#
# NOTE : ABOVE MENTIONED FINDINGS ARE A PROFESSIONAL OPINION AND NOT A FINAL DIAGNOSIS, ALL LABORATORY TESTS & OTHER INVESTIGATION RESULTS ARE TO BE CORELATED CLINIC-PATHOLOGICALLY, DISCREPANCIES, IF ANY, NECESSITATE REVIEW/REPEAT OF THE TESTS.
#
#
# CLINICAL CORELATION IS MANDATORY
#
#
#
# NOT VAILD FOR MEDICO PURPOSE
#
#
#
# LEGAL
#
#
# P
#
#
# ISO : 9001-2008
#
# # Diagnostic Point Pathology Labs
#
# EQUIPPED WITH COMPUTERISED AUTO CHEMISTRY, BLOOD GAS & HAEMATOLOGY ANALYSERS 101, 102, 107, 108, 109, 1st Floor, Agarwal Tower, Pkt. o & P Mkt. Dilshad Ga
#
# SARVODAYA HOSPITAL KJ-7, Kavi Nagar, Ghaziabad (U.P.)
#
#
# VERMA
#
# Patient Id
#
# Test
#
#
#  Dr. (Capt) Atul Kapila (Retd.) MD Path Regn No. MCI 3456
#
#
# Sri No. 1019
# RECEIPT ID 104194
#
# 0223/391503
# NoSP-25
#
# 16:13:21
#
#
# ## HAEMATOLOGY
#
# PERIPHERAL SMEAR
#
#  RBC'S:- Mild Anisocytosis Mild hypochromia, few micro and macrocytes no nucleated RBCs. No target cells seen.
#
#
# W.B.C'S:- No immature cells seen.
#
#
#
# PLATELETS:- platelets are adequate.
#
#
# **** End Of Report ****
#
# fol
#
#
# GHUZIABAD
#
# Ag
#
# No.-1
#
#
# it is computer generated Report Signatures Not Required
#
# NOTE : ABOVE MENTIONED FINDINGS ARE A PROFESSIONAL OPINION AND NOT A FINAL DIAGNOSIS, ALL LABORATORY TESTS & OTHER
#  INVESTIGATION RESULTS ARE TO BE CORELATED CLINIC-PATHOLOGICALLY, DISCREPANCIES, IF ANY, NECESSITATE REVIEW/REPEAT OF THE TESTS.
#
#
#
# FACILITIES : FOR HORMONES ASSAYS, FNAC, HISTOPATHOLOGY, BONE MARROW ASPIRATION & BIOPSY WITH MICRO PHOTOGRAPHS.
#
#
#
# Reported by ROH
#
#
#
# CLINICAL CORELATION IS MANDATORY
#
#
#
# NOT VAILD FOR MEDICO LEGAL PURPOSE
#
#
# P
#
#
#  ISO : 9001-2008 Diagnostic Point Pathology Labs EQUIPPED WITH COMPUTERISED AUTO CHEMISTRY, BLOOD GAS & HAEMATOLOGY ANALYSERS
#
# # 101, 102, 107, 108, 109, 1st Floor, Agarwal Tower, Pkt. o & P Mkt. Dilshad Garden, Delhi-95 Ph.:
#
# SARVODAYA HOSPITAL
#
#
#
# KJ-7, Kavi Nagar, Ghaziabad (U.P.)
#
#
# Dr. (Capt) Atul Kapila (Retd.) MD Path
#
# Regn No. MCI 3456
#
#
#
# Patient ID :
#
# Patient
#
# Referred VERMA
#
# Lab Serial No: 19
#
# Ward No : SP-25
#
# CR / UHD No : 0223/391503
#
#
#
#
#
#
# |                  |                        |
# |------------------|------------------------|
# | Receiving        | 18/Apr/2025 12:15:00PM |
# | Reporting Date : | 18/Apr/2025 3:17:39PM  |
# | Date TAT :       | 3 Hours 2 Minute       |
#
#
#
#
#
# | Investigation            | Observed Value    | Unit    | Biological Ref Interval    |
# |--------------------------|-------------------|---------|----------------------------|
# | AMMONIA Specimen : BLOOD | SEROLOGY 119.8\H  | ug/dl   | 17.00 90.00                |
#
#
#
# ** END OF REPORT **
#
# GIUZZABAD 2
#
#
#
#
#
#
#  Dr. ATUL KAPILA M.D. PATHOLOGY keat No.-MC 3456
#
#
# FACILITIES : FOR HORMONES ASSAYS, FNAC, HISTOPATHOLOGY MARROW ASPIRATION & BIOPSY WITH MICRO PHOTOGRAPHS
#
#
#
# NOTE : ABOVE MENTIONED FINDINGS ARE A PROFESSIONAL OPINION AND NOT A FINAL DIAGNOSIS, ALL LABORATORY TESTS & OTHER RESULTS ARE TO BE CORELATED CLINIC-PATHOLOGICALLY DISCREPANCIES, IF ANY, NECESSITATE REVIEW/REPEAT OF THE TESTS.
#
#
#
# INVESTIGATION
#
#
#
# NOT VAILD FOR MEDICO LEGAL PURPOSE
#
#
#
# CLINICAL CORELATION IS MANDATORY

# %% [markdown]
# ## Configure Bedrock Prompt

# %% [markdown]
# #### TODO: Your task is to edit the sample prompts and the field_definitions.csv file.

# %%
system_prompt = """
You are a medical data extraction assistant. 
Your task is to extract specific medical terms from the provided document according to the defined schema.
Please pay careful attention to:
1. Field locations and contexts specified in section headers
2. Special instructions for each field
3. Inclusion and exclusion criteria
4. Exact matching of field types and formats
5. Validation against any provided choices or calculations

For each field you extract, you must provide:
- variable_field_name: The extracted value from the document
- reasoning: Your explanation for why you chose this value and how it matches the field definition
- page_citation: Specific reference to where in the document you found this information

Format your response as a JSON object where each field contains these three elements.
"""

# %%
extraction_prompt = """
Analyze the following medical document segments and extract the requested fields. 
Each segment is preceded by a page number in the format --- Page <page number> ---.

Schema Information:
{schema}

Document Text:
{document}

For each field:
1. Extract the value according to the field definition and constraints
2. Explain your reasoning for choosing this value
3. Cite where in the document you found it

Return a JSON where each field has:
- variable_field_name: The extracted value (or null if not found)
- reasoning: Your one-sentence explanation for this extraction. DO NOT USE double quotes in the explanation.
- page_citation: Where you found it in the document

For fields with specific choices or calculations, ensure the extracted value matches one of the allowed options.
"""

# %% [markdown]
# ## Invoke Bedrock Prompt

# %% [markdown]
# #### Initialize Extractor class

# %%
extractor = Extractor()

# %% [markdown]
# #### Extract metadata from the markdown file, using the prompts and field definitions as inputs

# %%
extractor.extract_metadata(
    document_path="output/markdown_output/patient_02.md",
    system_prompt=system_prompt,
    extraction_prompt=extraction_prompt,
    field_definitions_path="field_definitions.csv"
)
# Out:
# Processing field: hospital_name
# Processing field: lab_name
# Processing field: physician_name
# Processing field: has_serum_specimen
# Processing field: serum_receiving_date
# Processing field: serum_reporting_date
# Processing field: serum_turnaround_time
# Processing field: bilirubin_total
# Processing field: bilirubin_total_unit
# Processing field: bilirubin_level
# Processing field: bilirubin_conjugated
# Processing field: bilirubin_conjugated_unit
# Processing field: bilirubin_conjugated_level
# Processing field: bilirubin_unconjugated
# Processing field: bilirubin_unconjugated_unit
# Processing field: bilirubin_unconjugated_level
# Processing field: has_blood_specimen
# Processing field: blood_receiving_date
# Processing field: blood_reporting_date
# Processing field: blood_turnaround_time
# Processing field: ammonia
# Processing field: ammonia_unit
# Processing field: ammonia_level

# %% [markdown]
# ## LLM Extraction Results

# %% [markdown]
# #### Initialize Evaluator class

# %%
evaluator = Evaluator()

# %% [markdown]
# #### Create comparison dataframe that joins the ground truth and LLM results

# %%
comparison_df = evaluator.create_comparison_df(
    ground_truth_path="ground_truth.csv",
    results_path="output/results/llm_results/patient_02_llm_results.csv"
)

# %%
comparison_df
# Out:
#                       field_name                       field_value  \
# 0                  hospital_name                Sarvodaya Hospital
# 1                       lab_name  Diagnostic Point Pathology Labs
# 2                 physician_name                       Atul Kapila
# 3             has_serum_specimen                               Yes
# 4           serum_receiving_date                           Unknown
# 5           serum_reporting_date                           Unknown
# 6          serum_turnaround_time                           Unknown
# 7                bilirubin_total                              9.42
# 8           bilirubin_total_unit                             mg/dl
# 9                bilirubin_level                                 H
# 10          bilirubin_conjugated                              7.79
# 11     bilirubin_conjugated_unit                             mg/dl
# 12    bilirubin_conjugated_level                                 H
# 13        bilirubin_unconjugated                              1.63
# 14   bilirubin_unconjugated_unit                             mg/dl
# 15  bilirubin_unconjugated_level                                 H
# 16            has_blood_specimen                               Yes
# 17          blood_receiving_date                           4/18/25
# 18          blood_reporting_date                           4/18/25
# 19         blood_turnaround_time                 3 Hours 2 Minutes
# 20                       ammonia                             119.8
# 21                  ammonia_unit                             ug/dl
# 22                 ammonia_level                                 H
#
#                                    llm_extraction  \
# 0                              SARVODAYA HOSPITAL
# 1                 Diagnostic Point Pathology Labs
# 2   {'first_name': 'Atul', 'last_name': 'Kapila'}
# 3                                             Yes
# 4                                     18/Apr/2025
# 5                                      04/18/2025
# 6                              2 Hours 29 Minutes
# 7                                            9.42
# 8                                           mg/dl
# 9                                               H
# 10                                           7.79
# 11                                          mg/dL
# 12                                              H
# 13                                           1.63
# 14                                          mg/dl
# 15                                              H
# 16                                            Yes
# 17                                     04/18/2025
# 18                                     04/18/2025
# 19                              2 Hours 29 Minute
# 20                                          119.8
# 21                                          ug/dl
# 22                                              H
#
#                                             reasoning  \
# 0   Identified the hospital name in the header sec...
# 1   The lab name is clearly printed in the header ...
# 2   Full physician name appears multiple times in ...
# 3   Serum is explicitly listed as a specimen type ...
# 4   The receiving date for the serum specimen is c...
# 5   Found the reporting date for the serum specime...
# 6   The turnaround time for the serum specimen is ...
# 7   Total bilirubin level is directly reported in ...
# 8   The total bilirubin value is reported with the...
# 9   Total bilirubin level is marked as 9.42 H, whi...
# 10  Extracted the conjugated bilirubin value direc...
# 11  The unit for conjugated bilirubin is explicitl...
# 12  The conjugated bilirubin level is 7.79 mg/dL a...
# 13  Extracted directly from the Liver Function Tes...
# 14  The unconjugated bilirubin test result in the ...
# 15  The unconjugated bilirubin value of 1.63 mg/dl...
# 16  Multiple blood specimens are referenced in the...
# 17  Found the receiving date in the third page of ...
# 18  Found the reporting date in the last page of t...
# 19  Found in the document on Page 1 under the TAT ...
# 20  The ammonia level is directly reported in the ...
# 21  The ammonia test result on the report specifie...
# 22  The ammonia value of 119.8 is marked with an H...
#
#                                         page_citation
# 0                    Page 1, repeated header sections
# 1                      Page 1, top of document header
# 2           Multiple pages, e.g. Page 1 first section
# 3   --- Page 1 ---, under Biochemistry results sec...
# 4      Page 1, last section with receiving date table
# 5   Page 1, Reporting Date line: 18/Apr/2025 3:17:...
# 6        Page 1, line with Date TAT 2 Hours 29 Minute
# 7   --- Page 1 --- Biochemistry section of lab rep...
# 8   Page 1, Biochemistry Table, Bilirubin Total co...
# 9   --- Page 1--- Biochemistry section, Bilirubin ...
# 10  Page 1, Biochemistry section of lab report, un...
# 11  Page 1, Biochemistry Results Table, Conjugated...
# 12  Page 1, Biochemistry Table - CONJUGATED (D. BI...
# 13                         Page 1, Biochemistry Table
# 14  Page 1 - Biochemistry section of laboratory re...
# 15         Page 1, Biochemistry section of lab report
# 16  Specimen sections on Pages 1-3, including Spec...
# 17  Page 1, Receiving section: 18/Apr/2025 12:15:00PM
# 18  Page 1, Reporting Date section showing 18/Apr/...
# 19                 Page 1: Date TAT 2 Hours 29 Minute
# 20              Page 1, Ammonia Investigation section
# 21     Page 1, Ammonia investigation row, Unit column
# 22                Page 1, Ammonia test result section

# %% [markdown]
# ## Perform LLM evaluation

# %% [markdown]
# #### Oftentimes, the extracted results do not perfectly match the ground truth results. As such, we may want to use additional evaluation methods, such as fuzzy match or LLM match to handle these imperfections. The following values can be specified for the "match_type" when calculating the accuracy of the extraction results.
# * EXACT
# * FUZZY
# * LLM
# * FUZZY_AND_LLM

# %%
exact_match_df = evaluator.calculate_accuracy(comparison_df, match_type="EXACT")
fuzzy_match_df = evaluator.calculate_accuracy(comparison_df, match_type="FUZZY")
llm_match_df = evaluator.calculate_accuracy(comparison_df, match_type="LLM")
llm_and_fuzzy_df = evaluator.calculate_accuracy(comparison_df, match_type="FUZZY_AND_LLM")
# Out:
# Exact match accuracy: 56.52%
# Fuzzy match accuracy: 82.61%
# LLM match accuracy: 86.96%
# LLM and Fuzzy match accuracy: 86.96%
